# %%
import pandas as pd
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from tensorflow.keras.models import Model
from keras.layers.core import Dense, Dropout
from transformers import TFBertModel,  BertConfig, BertTokenizerFast, RobertaTokenizer, RobertaModel, TFXLMRobertaModel
from transformers import AutoTokenizer,TFXLMRobertaModel, XLMRobertaModel,XLMTokenizer,XLMWithLMHeadModel
from transformers import XLMForSequenceClassification, XLMTokenizer, XLMConfig
import matplotlib.pyplot as plt
import numpy as np

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy()
# Out:
# Running on TPU  grpc://10.0.0.2:8470

# %%
train = pd.read_csv('../input/modified/train_modified.csv')
valid = pd.read_csv('../input/modified/val_modified.csv')
test = pd.read_csv('../input/modified/test_modified.csv')

# %%
xtrain, ytrain = train.Comment.values, train.Emotion.values
xvalid, yvalid = valid.Comment.values, valid.Emotion.values
xtest, ytest = test.Comment.values, test.Emotion.values

# %%
tokenizer = AutoTokenizer.from_pretrained("jplu/tf-xlm-roberta-base")
# tokenizer = XLMTokenizer.from_pretrained('xlm-mlm-tlm-xnli15-1024')
max_len = 200

# %%
xtrain_pad = tokenizer(
    text=train['Comment'].to_list(),
    add_special_tokens=True,
    max_length=max_len,
    truncation=True,
    padding=True, 
    return_tensors='tf',
    return_token_type_ids = False,
    return_attention_mask = False,
    verbose = True)

xvalid_pad = tokenizer(
    text=valid['Comment'].to_list(),
    add_special_tokens=True,
    max_length=max_len,
    truncation=True,
    padding=True, 
    return_tensors='tf',
    return_token_type_ids = False,
    return_attention_mask = False,
    verbose = True)

# xtrain_pad = tokenizer.encode(train['Comment'].to_list())
# xvalid_pad = tokenizer.encode(valid['Comment'].to_list())

# %%
def build_model(transformer):
    input_ids = Input(shape=(max_len,), dtype=tf.int32, name="input_ids")
    sequence_output = transformer(input_ids)[0]
    cls_token = sequence_output[:, 0, :]
    out = Dense(4, activation='softmax')(cls_token)

    model = Model(inputs=input_ids, outputs=out)
    loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
    model.compile(Adam(lr=1e-5), loss=loss, metrics=['accuracy'])

    return model

# %%
metrics = [tf.keras.metrics.SparseCategoricalAccuracy('accuracy', dtype=tf.float32)]
loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

# %%
with strategy.scope():
    transformer_model = TFXLMRobertaModel.from_pretrained("jplu/tf-xlm-roberta-base")
    model = build_model(transformer_model)

# %%
model.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_ids (InputLayer)       [(None, 200)]             0
# _________________________________________________________________
# tfxlm_roberta_model_1 (TFXLM ((None, 200, 768), (None, 278043648
# _________________________________________________________________
# tf_op_layer_strided_slice_1  [(None, 768)]             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 5383
# =================================================================
# Total params: 278,049,031
# Trainable params: 278,049,031
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(xtrain_pad['input_ids'], ytrain,epochs=100, validation_data= (xvalid_pad['input_ids'], yvalid), batch_size=32*strategy.num_replicas_in_sync)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 88s 7s/step - loss: 1.3914 - accuracy: 0.2592 - val_loss: 1.3956 - val_accuracy: 0.2335
# Epoch 2/100
# 12/12 [==============================] - 3s 279ms/step - loss: 1.3924 - accuracy: 0.2506 - val_loss: 1.3929 - val_accuracy: 0.2335
# Epoch 3/100
# 12/12 [==============================] - 3s 282ms/step - loss: 1.3871 - accuracy: 0.2566 - val_loss: 1.3904 - val_accuracy: 0.2335
# Epoch 4/100
# 12/12 [==============================] - 3s 279ms/step - loss: 1.3890 - accuracy: 0.2483 - val_loss: 1.3895 - val_accuracy: 0.2335
# Epoch 5/100
# 12/12 [==============================] - 3s 278ms/step - loss: 1.3862 - accuracy: 0.2596 - val_loss: 1.3880 - val_accuracy: 0.2364
# Epoch 6/100
# 12/12 [==============================] - 3s 281ms/step - loss: 1.3844 - accuracy: 0.2532 - val_loss: 1.3848 - val_accuracy: 0.2467
# Epoch 7/100
# 12/12 [==============================] - 3s 280ms/step - loss: 1.3852 - accuracy: 0.2702 - val_loss: 1.3761 - val_accuracy: 0.2981
# Epoch 8/100
# 12/12 [==============================] - 3s 279ms/step - loss: 1.3759 - accuracy: 0.3012 - val_loss: 1.3785 - val_accuracy: 0.2907
# Epoch 9/100
# 12/12 [==============================] - 3s 280ms/step - loss: 1.3740 - accuracy: 0.3085 - val_loss: 1.3547 - val_accuracy: 0.3392
# Epoch 10/100
# 12/12 [==============================] - 3s 280ms/step - loss: 1.3436 - accuracy: 0.3611 - val_loss: 1.3214 - val_accuracy: 0.3921
# Epoch 11/100
# 12/12 [==============================] - 3s 280ms/step - loss: 1.2745 - accuracy: 0.4692 - val_loss: 1.2192 - val_accuracy: 0.5110
# Epoch 12/100
# 12/12 [==============================] - 3s 280ms/step - loss: 1.1821 - accuracy: 0.5684 - val_loss: 1.1914 - val_accuracy: 0.5286
# Epoch 13/100
# 12/12 [==============================] - 3s 283ms/step - loss: 1.1019 - accuracy: 0.6559 - val_loss: 1.1331 - val_accuracy: 0.6050
# Epoch 14/100
# 12/12 [==============================] - 3s 283ms/step - loss: 1.0518 - accuracy: 0.6972 - val_loss: 1.1314 - val_accuracy: 0.6050
# Epoch 15/100
# 12/12 [==============================] - 3s 282ms/step - loss: 1.0275 - accuracy: 0.7165 - val_loss: 1.1203 - val_accuracy: 0.6197
# Epoch 16/100
# 12/12 [==============================] - 3s 280ms/step - loss: 1.0058 - accuracy: 0.7351 - val_loss: 1.1176 - val_accuracy: 0.6138
# Epoch 17/100
# 12/12 [==============================] - 3s 279ms/step - loss: 0.9762 - accuracy: 0.7654 - val_loss: 1.0735 - val_accuracy: 0.6637
# Epoch 18/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.9602 - accuracy: 0.7854 - val_loss: 1.0789 - val_accuracy: 0.6593
# Epoch 19/100
# 12/12 [==============================] - 3s 290ms/step - loss: 0.9621 - accuracy: 0.7814 - val_loss: 1.0890 - val_accuracy: 0.6461
# Epoch 20/100
# 12/12 [==============================] - 3s 279ms/step - loss: 0.9493 - accuracy: 0.7910 - val_loss: 1.1033 - val_accuracy: 0.6314
# Epoch 21/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.9319 - accuracy: 0.8140 - val_loss: 1.0892 - val_accuracy: 0.6446
# Epoch 22/100
# 12/12 [==============================] - 3s 283ms/step - loss: 0.9157 - accuracy: 0.8270 - val_loss: 1.0803 - val_accuracy: 0.6637
# Epoch 23/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.9114 - accuracy: 0.8333 - val_loss: 1.0567 - val_accuracy: 0.6858
# Epoch 24/100
# 12/12 [==============================] - 3s 279ms/step - loss: 0.8986 - accuracy: 0.8479 - val_loss: 1.0495 - val_accuracy: 0.6872
# Epoch 25/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.8963 - accuracy: 0.8473 - val_loss: 1.0232 - val_accuracy: 0.7210
# Epoch 26/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.8823 - accuracy: 0.8616 - val_loss: 1.0362 - val_accuracy: 0.6975
# Epoch 27/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.8732 - accuracy: 0.8722 - val_loss: 1.0308 - val_accuracy: 0.7093
# Epoch 28/100
# 12/12 [==============================] - 3s 279ms/step - loss: 0.8707 - accuracy: 0.8745 - val_loss: 0.9981 - val_accuracy: 0.7430
# Epoch 29/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.8632 - accuracy: 0.8795 - val_loss: 0.9971 - val_accuracy: 0.7445
# Epoch 30/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.8554 - accuracy: 0.8908 - val_loss: 1.0022 - val_accuracy: 0.7327
# Epoch 31/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.8512 - accuracy: 0.8925 - val_loss: 1.0041 - val_accuracy: 0.7357
# Epoch 32/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.8495 - accuracy: 0.8942 - val_loss: 0.9968 - val_accuracy: 0.7430
# Epoch 33/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.8474 - accuracy: 0.8982 - val_loss: 0.9971 - val_accuracy: 0.7430
# Epoch 34/100
# 12/12 [==============================] - 3s 284ms/step - loss: 0.8422 - accuracy: 0.9005 - val_loss: 0.9771 - val_accuracy: 0.7606
# Epoch 35/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.8352 - accuracy: 0.9092 - val_loss: 0.9848 - val_accuracy: 0.7592
# Epoch 36/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.8379 - accuracy: 0.9075 - val_loss: 0.9730 - val_accuracy: 0.7709
# Epoch 37/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.8338 - accuracy: 0.9121 - val_loss: 0.9649 - val_accuracy: 0.7768
# Epoch 38/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.8313 - accuracy: 0.9148 - val_loss: 0.9506 - val_accuracy: 0.7900
# Epoch 39/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.8258 - accuracy: 0.9191 - val_loss: 0.9662 - val_accuracy: 0.7739
# Epoch 40/100
# 12/12 [==============================] - 3s 279ms/step - loss: 0.8222 - accuracy: 0.9201 - val_loss: 0.9583 - val_accuracy: 0.7871
# Epoch 41/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.8179 - accuracy: 0.9261 - val_loss: 0.9792 - val_accuracy: 0.7606
# Epoch 42/100
# 12/12 [==============================] - 3s 282ms/step - loss: 0.8164 - accuracy: 0.9275 - val_loss: 1.0021 - val_accuracy: 0.7313
# Epoch 43/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.8152 - accuracy: 0.9318 - val_loss: 0.9976 - val_accuracy: 0.7386
# Epoch 44/100
# 12/12 [==============================] - 3s 282ms/step - loss: 0.8133 - accuracy: 0.9328 - val_loss: 0.9688 - val_accuracy: 0.7724
# Epoch 45/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.8113 - accuracy: 0.9338 - val_loss: 0.9558 - val_accuracy: 0.7856
# Epoch 46/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.8055 - accuracy: 0.9388 - val_loss: 0.9489 - val_accuracy: 0.7974
# Epoch 47/100
# 12/12 [==============================] - 3s 279ms/step - loss: 0.8045 - accuracy: 0.9414 - val_loss: 0.9675 - val_accuracy: 0.7709
# Epoch 48/100
# 12/12 [==============================] - 3s 284ms/step - loss: 0.8076 - accuracy: 0.9374 - val_loss: 0.9583 - val_accuracy: 0.7827
# Epoch 49/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.8025 - accuracy: 0.9434 - val_loss: 0.9713 - val_accuracy: 0.7665
# Epoch 50/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.8009 - accuracy: 0.9438 - val_loss: 0.9808 - val_accuracy: 0.7562
# Epoch 51/100
# 12/12 [==============================] - 3s 284ms/step - loss: 0.8021 - accuracy: 0.9424 - val_loss: 0.9617 - val_accuracy: 0.7797
# Epoch 52/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.8020 - accuracy: 0.9424 - val_loss: 0.9710 - val_accuracy: 0.7651
# Epoch 53/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.7972 - accuracy: 0.9481 - val_loss: 0.9702 - val_accuracy: 0.7695
# Epoch 54/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.7947 - accuracy: 0.9498 - val_loss: 0.9752 - val_accuracy: 0.7695
# Epoch 55/100
# 12/12 [==============================] - 3s 284ms/step - loss: 0.7922 - accuracy: 0.9524 - val_loss: 0.9576 - val_accuracy: 0.7856
# Epoch 56/100
# 12/12 [==============================] - 3s 279ms/step - loss: 0.7939 - accuracy: 0.9511 - val_loss: 0.9703 - val_accuracy: 0.7695
# Epoch 57/100
# 12/12 [==============================] - 3s 282ms/step - loss: 0.7933 - accuracy: 0.9511 - val_loss: 0.9858 - val_accuracy: 0.7533
# Epoch 58/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.7921 - accuracy: 0.9521 - val_loss: 0.9558 - val_accuracy: 0.7827
# Epoch 59/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.7899 - accuracy: 0.9551 - val_loss: 0.9757 - val_accuracy: 0.7651
# Epoch 60/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.7907 - accuracy: 0.9544 - val_loss: 0.9726 - val_accuracy: 0.7680
# Epoch 61/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.7891 - accuracy: 0.9561 - val_loss: 0.9721 - val_accuracy: 0.7739
# Epoch 62/100
# 12/12 [==============================] - 3s 283ms/step - loss: 0.7919 - accuracy: 0.9534 - val_loss: 0.9688 - val_accuracy: 0.7695
# Epoch 63/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.7900 - accuracy: 0.9547 - val_loss: 0.9697 - val_accuracy: 0.7695
# Epoch 64/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.7911 - accuracy: 0.9531 - val_loss: 0.9783 - val_accuracy: 0.7636
# Epoch 65/100
# 12/12 [==============================] - 3s 282ms/step - loss: 0.7879 - accuracy: 0.9561 - val_loss: 0.9714 - val_accuracy: 0.7695
# Epoch 66/100
# 12/12 [==============================] - 3s 284ms/step - loss: 0.7880 - accuracy: 0.9564 - val_loss: 0.9632 - val_accuracy: 0.7783
# Epoch 67/100
# 12/12 [==============================] - 3s 282ms/step - loss: 0.7883 - accuracy: 0.9554 - val_loss: 0.9714 - val_accuracy: 0.7695
# Epoch 68/100
# 12/12 [==============================] - 3s 284ms/step - loss: 0.7861 - accuracy: 0.9581 - val_loss: 0.9834 - val_accuracy: 0.7592
# Epoch 69/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.7881 - accuracy: 0.9567 - val_loss: 0.9419 - val_accuracy: 0.8003
# Epoch 70/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.7896 - accuracy: 0.9544 - val_loss: 0.9721 - val_accuracy: 0.7709
# Epoch 71/100
# 12/12 [==============================] - 3s 282ms/step - loss: 0.7895 - accuracy: 0.9544 - val_loss: 0.9879 - val_accuracy: 0.7518
# Epoch 72/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.7880 - accuracy: 0.9567 - val_loss: 0.9500 - val_accuracy: 0.7915
# Epoch 73/100
# 12/12 [==============================] - 3s 279ms/step - loss: 0.7866 - accuracy: 0.9581 - val_loss: 0.9727 - val_accuracy: 0.7651
# Epoch 74/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.7831 - accuracy: 0.9607 - val_loss: 0.9487 - val_accuracy: 0.7900
# Epoch 75/100
# 12/12 [==============================] - 3s 279ms/step - loss: 0.7845 - accuracy: 0.9604 - val_loss: 0.9687 - val_accuracy: 0.7709
# Epoch 76/100
# 12/12 [==============================] - 3s 282ms/step - loss: 0.7839 - accuracy: 0.9607 - val_loss: 0.9660 - val_accuracy: 0.7768
# Epoch 77/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.7835 - accuracy: 0.9611 - val_loss: 0.9530 - val_accuracy: 0.7856
# Epoch 78/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.7815 - accuracy: 0.9631 - val_loss: 0.9661 - val_accuracy: 0.7753
# Epoch 79/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.7825 - accuracy: 0.9611 - val_loss: 0.9469 - val_accuracy: 0.7959
# Epoch 80/100
# 12/12 [==============================] - 3s 282ms/step - loss: 0.7827 - accuracy: 0.9604 - val_loss: 0.9605 - val_accuracy: 0.7783
# Epoch 81/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.7820 - accuracy: 0.9621 - val_loss: 0.9599 - val_accuracy: 0.7812
# Epoch 82/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.7817 - accuracy: 0.9621 - val_loss: 0.9408 - val_accuracy: 0.7974
# Epoch 83/100
# 12/12 [==============================] - 4s 327ms/step - loss: 0.7845 - accuracy: 0.9591 - val_loss: 0.9630 - val_accuracy: 0.7768
# Epoch 84/100
# 12/12 [==============================] - 3s 278ms/step - loss: 0.7822 - accuracy: 0.9617 - val_loss: 0.9447 - val_accuracy: 0.7944
# Epoch 85/100
# 12/12 [==============================] - 3s 278ms/step - loss: 0.7813 - accuracy: 0.9631 - val_loss: 0.9759 - val_accuracy: 0.7680
# Epoch 86/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.7834 - accuracy: 0.9604 - val_loss: 0.9452 - val_accuracy: 0.7915
# Epoch 87/100
# 12/12 [==============================] - 3s 282ms/step - loss: 0.7813 - accuracy: 0.9627 - val_loss: 0.9442 - val_accuracy: 0.7944
# Epoch 88/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.7819 - accuracy: 0.9624 - val_loss: 0.9740 - val_accuracy: 0.7621
# Epoch 89/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.7820 - accuracy: 0.9621 - val_loss: 0.9392 - val_accuracy: 0.8032
# Epoch 90/100
# 12/12 [==============================] - 3s 282ms/step - loss: 0.7813 - accuracy: 0.9624 - val_loss: 0.9675 - val_accuracy: 0.7739
# Epoch 91/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.7826 - accuracy: 0.9614 - val_loss: 0.9462 - val_accuracy: 0.7944
# Epoch 92/100
# 12/12 [==============================] - 3s 279ms/step - loss: 0.7796 - accuracy: 0.9644 - val_loss: 0.9638 - val_accuracy: 0.7783
# Epoch 93/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.7800 - accuracy: 0.9637 - val_loss: 0.9651 - val_accuracy: 0.7753
# Epoch 94/100
# 12/12 [==============================] - 3s 277ms/step - loss: 0.7795 - accuracy: 0.9647 - val_loss: 0.9592 - val_accuracy: 0.7797
# Epoch 95/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.7820 - accuracy: 0.9621 - val_loss: 0.9483 - val_accuracy: 0.7930
# Epoch 96/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.7797 - accuracy: 0.9641 - val_loss: 0.9597 - val_accuracy: 0.7768
# Epoch 97/100
# 12/12 [==============================] - 3s 279ms/step - loss: 0.7813 - accuracy: 0.9624 - val_loss: 0.9565 - val_accuracy: 0.7900
# Epoch 98/100
# 12/12 [==============================] - 3s 279ms/step - loss: 0.7792 - accuracy: 0.9644 - val_loss: 0.9585 - val_accuracy: 0.7797
# Epoch 99/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.7798 - accuracy: 0.9641 - val_loss: 0.9481 - val_accuracy: 0.7930
# Epoch 100/100
# 12/12 [==============================] - 3s 281ms/step - loss: 0.7785 - accuracy: 0.9657 - val_loss: 0.9592 - val_accuracy: 0.7783

# %%
def plot_learning_curve(history):
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    accuracy = history.history['accuracy']
    val_accuracy = history.history['val_accuracy']

    plt.plot(loss, label='loss')
    plt.plot(val_loss,label='val loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(['loss','val_loss'],loc='upper right')
    plt.show()
 

    plt.plot(accuracy, label='accuracy')
    plt.plot(val_accuracy,label='val accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(['accuracy','val accuracy'],loc='upper right')
    plt.show()

# %%
plot_learning_curve(history)

# %%
xtest_pad = tokenizer(
    text=test['Comment'].to_list(),
    add_special_tokens=True,
    max_length=max_len,
    truncation=True,
    padding=True, 
    return_tensors='tf',
    return_token_type_ids = False,
    return_attention_mask = False,
    verbose = True)
model.evaluate(xtest_pad['input_ids'],ytest)
# Out:
# 21/21 [==============================] - 12s 585ms/step - loss: 0.9561 - accuracy: 0.7838
# [0.9560555815696716, 0.7838258147239685]

# %%
test_string = 'मैं बहुत खुश हूँ'

# %%
def prediction(model,tokenizer,input_string):
    
    padded_tokens = tokenizer(
    text=[input_string],
    add_special_tokens=True,
    max_length=max_len,
    truncation=True,
    padding=True, 
    return_tensors='tf',
    return_token_type_ids = False,
    return_attention_mask = False,
    verbose = True)
    
    prediction = model.predict(padded_tokens['input_ids'])
    print(prediction)
    conversion_dict = {0:'joy',1:'fear',2:'anger',3:'sadness'}
    
    return conversion_dict[np.argmax(prediction)]

# %%
# prediction(model,tokenizer,"நான் மிகவும் மகிழ்ச்சியடைகிறேன்")
prediction(model,tokenizer,"I am Happy")
# Out:
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# <ipython-input-114-1fae4bd3f80c> in <module>
#       1 # prediction(model,tokenizer,"நான் மிகவும் மகிழ்ச்சியடைகிறேன்")
# ----> 2 prediction(model,tokenizer,"I am Happy")
#
# <ipython-input-113-a464e2dc75f8> in prediction(model, tokenizer, input_string)
#      12     verbose = True)
#      13
# ---> 14     prediction = model.predict(padded_tokens['input_ids'])
#      15     print(prediction)
#      16     conversion_dict = {0:'joy',1:'fear',2:'anger',3:'sadness'}
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     128       raise ValueError('{} is not supported in multi-worker mode.'.format(
#     129           method.__name__))
# --> 130     return method(self, *args, **kwargs)
#     131
#     132   return tf_decorator.make_decorator(
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1610                   outputs, batch_outputs)
#    1611             end_step = step + data_handler.step_increment
# -> 1612             callbacks.on_predict_batch_end(end_step, {'outputs': batch_outputs})
#    1613       callbacks.on_predict_end()
#    1614     all_outputs = nest.map_structure_up_to(batch_outputs, concat, outputs)
#
# /opt/conda/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/data_adapter.py in catch_stop_iteration(self)
#    1167     try:
#    1168       yield
# -> 1169       context.async_wait()
#    1170     except (StopIteration, errors.OutOfRangeError):
#    1171       if self._inferred_steps is None:
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/context.py in async_wait()
#    2317   an error state.
#    2318   """
# -> 2319   context().sync_executors()
#    2320
#    2321
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/context.py in sync_executors(self)
#     656     """
#     657     if self._context_handle:
# --> 658       pywrap_tfe.TFE_ContextSyncExecutors(self._context_handle)
#     659     else:
#     660       raise ValueError("Context is not initialized.")
#
# UnimplementedError: 9 root error(s) found.
#   (0) Unimplemented: {{function_node __inference_predict_function_551330}} Compilation failure: Dynamic shape is not supported for non trivial window: size=1x5 pad=0_0x4_0
# 	 [[{{node functional_9/tfxlm_roberta_model_4/roberta/embeddings/Cumsum}}]]
# 	TPU compilation failed
# 	 [[tpu_compile_succeeded_assert/_9096231628060456453/_4]]
# 	 [[tpu_compile_succeeded_assert/_9096231628060456453/_4/_199]]
#   (1) Unimplemented: {{function_node __inference_predict_function_551330}} Compilation failure: Dynamic shape is not supported for non trivial window: size=1x5 pad=0_0x4_0
# 	 [[{{node functional_9/tfxlm_roberta_model_4/roberta/embeddings/Cumsum}}]]
# 	TPU compilation failed
# 	 [[tpu_compile_succeeded_assert/_9096231628060456453/_4]]
# 	 [[cluster_predict_function/control_after/_1/_283]]
#   (2) Unimplemented: {{function_node __inference_predict_function_551330}} Compilation failure: Dynamic shape is not supported for non trivial window: size=1x5 pad=0_0x4_0
# 	 [[{{node functional_9/tfxlm_roberta_model_4/roberta/embeddings/Cumsum}}]]
# 	TPU compilation failed
# 	 [[tpu_compile_succeeded_assert/_9096231628060456453/_4]]
# 	 [[cluster_predict_function/control_after/_1/_263]]
#   (3) Unimplemented: {{function_node __inference_predict_function_551330}} Compilation failure: Dynamic shape is not supported for non trivial window: size=1x5 pad=0_0x4_0
# 	 [[{{node functional_9/tfxlm_roberta_model_4/roberta/embeddings/Cumsum}}]]
# 	TPU compilation failed
# 	 [[tpu_compile_succeeded_assert/_9096231628060456453/_4]]
# 	 [[cluster_predict_function/control_after/_1/_267]]
#   (4) Unimplemented: {{function_node __inference_predict_function_551330}} Compilation failure: Dynamic shape is not supported for non trivial window: size=1x5 pad=0_0x4_0
# 	 [[{{node functional_9/tfxlm_roberta_model_4/roberta/embeddings/Cumsum}}]]
# 	TPU compilation failed
# 	 [[tpu_compile_succeeded_assert/_9096231628060456453/_4]]
# 	 [[cluster_predict_function/control_after/_1/_287]]
#   (5) Unimplemented: {{function_node __inference_predict_function_551330}} Compilation failure: Dynamic shape is not supported for non trivial window: size=1x5 pad=0_0x4_0
# 	 [[{{node functional_9/tfxlm_roberta_model_4/roberta/embeddings/Cumsum}}]]
# 	TPU compilation failed
# 	 [[tpu_compile_succeeded_assert/_9096231628060456453/_4]]
# 	 [[tpu_compile_succeeded_assert/_9096231628060456453/_4/_175]]
#   (6) Unimplemented: {{function_node __inference_predict_function_551330}} Compilation failure: Dynamic shape is not supported for non trivial window: size=1x5 pad=0_0x4_0
# 	 [[{{node functional_9/tfxlm_roberta_model_4/roberta/embeddings/Cumsum}}]]
# 	TPU compilation failed
# 	 [[tpu_compile_succeeded_assert/_9096231628060456453/_4]]
# 	 [[tpu_compile_succeeded_assert/_9096231628060456453/_4/_187]]
#   (7) Unimplemented: {{function_node __inference_predict_function_551330}} Compilation failure: Dynamic shape is not supported for non trivial window: size=1x5 pad=0_0x4_0
# 	 [[{{node functional_9/tfxlm_roberta_model_4/roberta/embeddings/Cumsum}}]]
# 	TPU compilation failed
# 	 [[tpu_compile_succeeded_assert/_9096231628060456453/_4 ... [truncated]

# %%
model.save("best_xlm.h5")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-115-38812627ed7a> in <module>
# ----> 1 model.save("/kaggle/output/best_xlm.h5")
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in save(self, filepath, overwrite, include_optimizer, save_format, signatures, options)
#    1977     """
#    1978     save.save_model(self, filepath, overwrite, include_optimizer, save_format,
# -> 1979                     signatures, options)
#    1980
#    1981   def save_weights(self,
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/saving/save.py in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options)
#     129           'or using `save_weights`.')
#     130     hdf5_format.save_model_to_hdf5(
# --> 131         model, filepath, overwrite, include_optimizer)
#     132   else:
#     133     saved_model_save.save(model, filepath, overwrite, include_optimizer,
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/saving/hdf5_format.py in save_model_to_hdf5(model, filepath, overwrite, include_optimizer)
#     100         return
#     101
# --> 102     f = h5py.File(filepath, mode='w')
#     103     opened_new_file = True
#     104   else:
#
# /opt/conda/lib/python3.7/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 408                                swmr=swmr)
#     409
#     410             if isinstance(libver, tuple):
#
# /opt/conda/lib/python3.7/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     177         fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     178     elif mode == 'w':
# --> 179         fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#     180     elif mode == 'a':
#     181         # Open in append mode (read/write).
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.create()
#
# OSError: Unable to create file (unable to open file: name = '/kaggle/output/best_xlm.h5', errno = 2, error message = 'No such file or directory', flags = 13, o_flags = 242)
